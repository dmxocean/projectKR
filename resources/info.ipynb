# %%
import pandas as pd

df = pd.read_csv("data.csv")

df.head()
# Out:
#         Make              Model  Year                       Drive Fuel Type  \
# 0       Ford         Bronco 4WD  1986  4-Wheel or All-Wheel Drive   Regular
# 1       Ford          LTD Wagon  1984                         NaN   Regular
# 2  Chevrolet     S10 Pickup 2WD  1984               2-Wheel Drive   Regular
# 3      Dodge  Ram 50 Pickup 2WD  1984               2-Wheel Drive   Regular
# 4       Ford  Ranger Pickup 2WD  1984               2-Wheel Drive   Regular
#
#    Cylinders     Transmission        Vehicle Size Class  You Save/Spend  \
# 0        8.0     Manual 4-spd  Special Purpose Vehicles          -11250
# 1        6.0  Automatic 4-spd    Midsize Station Wagons           -4750
# 2        4.0     Manual 4-spd   Small Pickup Trucks 2WD           -2250
# 3        4.0     Manual 5-spd   Small Pickup Trucks 2WD           -4000
# 4        4.0  Automatic 3-spd   Small Pickup Trucks 2WD           -4750
#
#    Annual Petroleum Consumption For Fuel Type1  ...  Engine descriptor  \
# ...

# %%
len(df.columns.to_list())
# Out:
# 21

# %%
df.columns.tolist()
# Out:
# ['Make',
#  'Model',
#  'Year',
#  'Drive',
#  'Fuel Type',
#  'Cylinders',
#  'Transmission',
#  'Vehicle Size Class',
#  'You Save/Spend',
#  'Annual Petroleum Consumption For Fuel Type1',
#  'Co2 Fuel Type1',
#  'Engine descriptor',
#  'EPA Fuel Economy Score',
#  'GHG Score',
#  'ID',
#  'MPG Data',
#  'Electric motor',
#  'T Charger',
#  'S Charger',
#  'City gasoline consumption',
#  'City electricity consumption']
